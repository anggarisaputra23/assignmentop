# %% [markdown]
# <a href="https://colab.research.google.com/github/anggarisaputra23/assignmentop/blob/main/Genetic_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assume the following are defined outside the function
# production_line_tasks: a list of dictionaries, each representing a task
#   e.g., [{'name': 'TaskA', 'duration': 5, 'dependencies': []}, ...]
#   'dependencies' is a list of names of tasks that must complete before this task starts.
# machines: a list of available machines, e.g., ['Machine1', 'Machine2']
# machine_speeds: a dictionary mapping machine names to their processing speed relative to a base, e.g., {'Machine1': 1.0, 'Machine2': 1.2}

import random
import copy
import itertools

# --- Fitness Evaluation for Scheduling ---
def evaluate_scheduling_fitness(schedule, production_line_tasks, machine_speeds):
  """
  Evaluates the fitness of a scheduling chromosome.
  Fitness is the negative of the total completion time (makespan),
  as we want to minimize makespan. Higher fitness is better.
  A valid schedule must respect task dependencies.
  """
  # Decode the schedule chromosome into a sequence of task assignments to machines
  # The chromosome is a permutation of tasks. We need to assign them to machines.
  # A simple decoding could be assigning tasks sequentially to available machines.
  # This is a simplified decoding; more complex decodings exist.

  # Let's assume the chromosome is a permutation of task indices.
  # We will assign tasks in this order to the machine that becomes free earliest.

  num_tasks = len(production_line_tasks)
  num_machines = len(machine_speeds)
  machine_finish_times = {machine: 0 for machine in machine_speeds}
  task_completion_times = {}

  # Create a dictionary for task objects for easy lookup
  task_dict = {task['name']: task for task in production_line_tasks}

  # Create a dictionary to track dependencies completion
  task_dependencies_met = {task['name']: False for task in production_line_tasks}
  # Mark tasks with no dependencies as met initially
  for task in production_line_tasks:
      if not task.get('dependencies'):
          task_dependencies_met[task['name']] = True

  # Convert chromosome (task index permutation) to task name permutation
  task_order = [production_line_tasks[i]['name'] for i in schedule]

  # Process tasks in the order given by the schedule
  for task_name in task_order:
      task = task_dict[task_name]
      dependencies_met = all(task_completion_times.get(dep, 0) > 0 for dep in task.get('dependencies', []))
      if not dependencies_met:
          # This schedule is invalid as dependencies are not met in order.
          # Return a very low fitness value.
          return -float('inf')

      # Find the machine that becomes free earliest
      earliest_machine = min(machine_finish_times, key=machine_finish_times.get)
      earliest_free_time = machine_finish_times[earliest_machine]

      # Calculate task start time on this machine
      dependency_completion_time = 0
      for dep_name in task.get('dependencies', []):
          dependency_completion_time = max(dependency_completion_time, task_completion_times.get(dep_name, 0))

      task_start_time = max(earliest_free_time, dependency_completion_time)

      # Calculate task duration on this machine considering machine speed
      task_duration = task['duration'] / machine_speeds[earliest_machine]

      # Calculate task completion time
      task_completion_time = task_start_time + task_duration

      # Update machine finish time and task completion time
      machine_finish_times[earliest_machine] = task_completion_time
      task_completion_times[task_name] = task_completion_time

  # The total completion time (makespan) is the maximum of all machine finish times
  makespan = max(machine_finish_times.values())

  # Fitness is the negative of the makespan (since we minimize makespan)
  return -makespan

# --- Chromosome Representation for Scheduling ---
# A chromosome is a permutation of task indices.
# The length of the chromosome is the number of tasks.
def create_scheduling_chromosome(num_tasks):
  """Creates a random permutation of task indices."""
  chromosome = list(range(num_tasks))
  random.shuffle(chromosome)
  return chromosome

# --- Selection ---
# Reuse the previous select_parent function. It works with any fitness scores.

# --- Crossover for Scheduling (Order Crossover - OX) ---
# Since the chromosome is a permutation, simple one-point crossover can break the permutation property.
# Order Crossover (OX) preserves the permutation.
def order_crossover(parent1, parent2):
  """Performs Order Crossover (OX) on two parent chromosomes (permutations)."""
  size = len(parent1)
  a, b = random.sample(range(size), 2)
  if a > b:
    a, b = b, a

  # Copy a segment from parent1 to child1
  child1 = [None] * size
  child1[a:b+1] = parent1[a:b+1]

  # Fill the remaining slots in child1 with elements from parent2
  # in the order they appear after point b, wrapping around
  p2_index = (b + 1) % size
  c1_index = (b + 1) % size
  while None in child1:
      if parent2[p2_index] not in child1:
          child1[c1_index] = parent2[p2_index]
          c1_index = (c1_index + 1) % size
      p2_index = (p2_index + 1) % size

  # Repeat for child2 with parent1 and parent2 swapped
  child2 = [None] * size
  child2[a:b+1] = parent2[a:b+1]

  p1_index = (b + 1) % size
  c2_index = (b + 1) % size
  while None in child2:
      if parent1[p1_index] not in child2:
          child2[c2_index] = parent1[p1_index]
          c2_index = (c2_index + 1) % size
      p1_index = (p1_index + 1) % size

  return child1, child2


# --- Mutation for Scheduling (Swap Mutation) ---
# Swap mutation preserves the permutation.
def swap_mutation(chromosome, mutation_rate):
  """Mutates a permutation chromosome by swapping two elements with a given probability."""
  mutated_chromosome = chromosome[:]
  if random.random() < mutation_rate:
    idx1, idx2 = random.sample(range(len(mutated_chromosome)), 2)
    mutated_chromosome[idx1], mutated_chromosome[idx2] = mutated_chromosome[idx2], mutated_chromosome[idx1]
  return mutated_chromosome

# --- Genetic Algorithm for Scheduling ---
def genetic_algorithm_scheduling(production_line_tasks, machine_speeds, population_size, generations, mutation_rate):
  num_tasks = len(production_line_tasks)
  if num_tasks == 0:
      return [] # No tasks to schedule

  # Initialize population
  population = [create_scheduling_chromosome(num_tasks) for _ in range(population_size)]

  best_overall_chromosome = None
  best_overall_fitness = -float('inf')

  for generation in range(generations):
    # Evaluate fitness for the current population
    fitness_scores = [evaluate_scheduling_fitness(chromosome, production_line_tasks, machine_speeds) for chromosome in population]

    # Find the best chromosome in the current generation
    current_best_fitness = max(fitness_scores)
    current_best_index = fitness_scores.index(current_best_fitness)
    current_best_chromosome = population[current_best_index]

    # Update overall best if the current generation's best is better
    if current_best_fitness > best_overall_fitness:
        best_overall_fitness = current_best_fitness
        best_overall_chromosome = copy.deepcopy(current_best_chromosome)

    # Print best fitness of the generation
    print(f"Generation {generation}: Best Fitness = {current_best_fitness} (Makespan = {-current_best_fitness})")

    # Selection (using the existing select_parent)
    parents = []
    # Handle cases where all fitness scores are -inf (invalid schedules)
    valid_indices = [i for i, fitness in enumerate(fitness_scores) if fitness > -float('inf')]
    if not valid_indices:
        print("Warning: All schedules in this generation are invalid. Re-initializing population.")
        population = [create_scheduling_chromosome(num_tasks) for _ in range(population_size)]
        continue # Skip crossover and mutation for this generation

    valid_population = [population[i] for i in valid_indices]
    valid_fitness_scores = [fitness_scores[i] for i in valid_indices]

    if len(valid_population) < 2:
         # If less than 2 valid parents, just duplicate the valid ones or re-initialize
         print("Warning: Less than 2 valid parents available. Re-initializing population.")
         population = [create_scheduling_chromosome(num_tasks) for _ in range(population_size)]
         continue

    for _ in range(population_size):
      parents.append(select_parent(valid_population, valid_fitness_scores))

    # Create next generation through crossover and mutation
    next_population = []
    # Ensure an even number of parents for crossover
    if len(parents) % 2 != 0:
        parents.append(random.choice(parents)) # Add a random parent to make it even

    for i in range(0, len(parents), 2):
      parent1 = parents[i]
      parent2 = parents[i+1]
      child1, child2 = order_crossover(parent1, parent2)
      next_population.append(swap_mutation(child1, mutation_rate))
      next_population.append(swap_mutation(child2, mutation_rate))

    population = next_population[:population_size] # Ensure population size is maintained

  # Return the best chromosome found across all generations
  return best_overall_chromosome

# Example Usage:

# Define your production line tasks
# Duration is a base duration, actual duration depends on the assigned machine speed
production_line_tasks = [
    {'name': 'TaskA', 'duration': 10, 'dependencies': []},
    {'name': 'TaskB', 'duration': 8, 'dependencies': ['TaskA']},
    {'name': 'TaskC', 'duration': 12, 'dependencies': ['TaskA']},
    {'name': 'TaskD', 'duration': 7, 'dependencies': ['TaskB', 'TaskC']},
    {'name': 'TaskE', 'duration': 9, 'dependencies': ['TaskD']},
]

# Define your machines and their speeds
machines = ['Machine1', 'Machine2']
machine_speeds = {'Machine1': 1.0, 'Machine2': 1.5} # Machine2 is 1.5 times faster

# Genetic Algorithm Parameters
population_size = 100
generations = 500
mutation_rate = 0.1

# Run the genetic algorithm
best_schedule_chromosome = genetic_algorithm_scheduling(
    production_line_tasks,
    machine_speeds,
    population_size,
    generations,
    mutation_rate
)

print("\nBest Schedule Chromosome (Task Indices Permutation):", best_schedule_chromosome)

# To interpret the best schedule, you would decode the chromosome:
# Example decoding to show task order:
if best_schedule_chromosome is not None:
    best_task_order = [production_line_tasks[i]['name'] for i in best_schedule_chromosome]
    print("Best Task Order:", best_task_order)
    # You could further simulate this schedule to get the actual start/finish times on each machine

    # Calculate the fitness of the best chromosome found
    best_makespan_fitness = evaluate_scheduling_fitness(
        best_schedule_chromosome,
        production_line_tasks,
        machine_speeds
    )
    print(f"Achieved Makespan: {-best_makespan_fitness}")
# Out:
# Generation 0: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 1: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 2: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 3: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 4: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 5: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 6: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 7: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 8: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 9: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 10: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 11: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 12: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 13: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 14: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 15: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 16: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 17: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 18: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 19: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 20: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 21: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 22: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 23: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 24: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 25: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 26: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 27: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 28: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 29: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 30: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 31: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 32: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 33: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 34: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 35: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 36: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 37: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 38: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 39: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 40: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 41: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 42: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 43: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 44: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 45: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 46: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 47: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 48: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 49: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 50: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 51: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 52: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 53: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 54: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 55: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 56: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 57: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 58: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 59: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 60: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 61: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 62: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 63: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 64: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 65: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 66: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 67: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 68: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 69: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 70: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 71: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 72: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 73: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 74: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 75: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 76: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 77: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 78: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 79: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 80: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 81: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 82: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 83: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 84: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 85: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 86: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 87: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 88: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 89: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 90: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 91: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 92: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 93: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 94: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 95: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 96: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 97: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 98: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 99: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 100: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 101: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 102: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 103: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 104: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 105: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 106: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 107: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 108: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 109: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 110: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 111: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 112: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 113: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 114: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 115: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 116: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 117: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 118: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 119: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 120: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 121: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 122: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 123: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 124: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 125: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 126: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 127: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 128: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 129: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 130: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 131: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 132: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 133: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 134: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 135: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 136: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 137: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 138: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 139: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 140: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 141: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 142: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 143: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 144: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 145: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 146: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 147: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 148: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 149: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 150: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 151: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 152: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 153: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 154: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 155: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 156: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 157: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 158: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 159: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 160: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 161: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 162: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 163: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 164: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 165: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 166: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 167: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 168: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 169: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 170: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 171: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 172: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 173: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 174: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 175: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 176: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 177: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 178: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 179: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 180: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 181: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 182: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 183: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 184: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 185: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 186: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 187: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 188: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 189: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 190: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 191: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 192: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 193: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 194: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 195: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 196: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 197: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 198: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 199: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 200: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 201: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 202: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 203: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 204: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 205: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 206: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 207: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 208: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 209: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 210: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 211: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 212: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 213: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 214: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 215: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 216: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 217: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 218: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 219: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 220: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 221: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 222: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 223: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 224: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 225: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 226: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 227: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 228: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 229: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 230: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 231: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 232: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 233: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 234: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 235: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 236: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 237: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 238: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 239: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 240: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 241: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 242: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 243: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 244: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 245: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 246: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 247: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 248: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 249: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 250: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 251: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 252: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 253: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 254: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 255: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 256: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 257: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 258: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 259: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 260: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 261: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 262: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 263: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 264: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 265: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 266: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 267: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 268: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 269: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 270: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 271: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 272: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 273: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 274: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 275: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 276: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 277: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 278: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 279: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 280: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 281: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 282: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 283: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 284: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 285: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 286: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 287: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 288: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 289: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 290: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 291: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 292: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 293: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 294: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 295: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 296: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 297: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 298: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 299: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 300: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 301: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 302: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 303: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 304: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 305: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 306: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 307: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 308: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 309: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 310: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 311: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 312: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 313: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 314: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 315: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 316: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 317: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 318: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 319: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 320: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 321: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 322: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 323: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 324: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 325: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 326: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 327: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 328: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 329: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 330: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 331: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 332: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 333: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 334: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 335: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 336: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 337: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 338: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 339: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 340: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 341: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 342: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 343: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 344: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 345: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 346: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 347: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 348: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 349: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 350: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 351: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 352: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 353: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 354: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 355: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 356: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 357: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 358: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 359: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 360: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 361: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 362: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 363: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 364: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 365: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 366: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 367: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 368: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 369: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 370: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 371: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 372: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 373: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 374: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 375: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 376: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 377: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 378: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 379: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 380: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 381: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 382: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 383: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 384: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 385: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 386: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 387: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 388: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 389: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 390: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 391: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 392: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 393: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 394: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 395: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 396: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 397: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 398: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 399: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 400: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 401: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 402: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 403: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 404: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 405: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 406: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 407: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 408: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 409: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 410: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 411: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 412: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 413: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 414: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 415: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 416: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 417: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 418: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 419: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 420: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 421: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 422: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 423: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 424: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 425: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 426: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 427: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 428: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 429: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 430: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 431: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 432: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 433: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 434: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 435: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 436: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 437: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 438: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 439: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 440: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 441: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 442: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 443: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 444: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 445: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 446: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 447: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 448: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 449: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 450: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 451: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 452: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 453: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 454: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 455: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 456: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 457: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 458: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 459: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 460: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 461: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 462: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 463: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 464: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 465: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 466: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 467: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 468: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 469: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 470: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 471: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 472: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 473: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 474: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 475: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 476: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 477: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 478: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 479: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 480: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 481: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 482: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 483: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 484: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 485: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 486: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 487: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 488: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 489: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 490: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 491: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 492: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 493: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 494: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 495: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 496: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 497: Best Fitness = -31.0 (Makespan = 31.0)
# Generation 498: Best Fitness = -35.66666666666667 (Makespan = 35.66666666666667)
# Generation 499: Best Fitness = -31.0 (Makespan = 31.0)
#
# Best Schedule Chromosome (Task Indices Permutation): [0, 2, 1, 3, 4]
# Best Task Order: ['TaskA', 'TaskC', 'TaskB', 'TaskD', 'TaskE']
# Achieved Makespan: 31.0
