# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
from scipy import stats
import math

# %%
# Data for Perkotaan
data_perkotaan = {
    'Rumah Tangga': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
    'Perkotaan': [110, 102, 98, 107, 120, 125, 115, 95, 122, 112]
}

# Data for Perdesaan
data_perdesaan = {
    'Rumah Tangga': ['P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y'],
    'Perdesaan': [54, 45, 60, 55, 75, 72, 62, 65, 85, 35]
}

# Create DataFrames
df_perkotaan = pd.DataFrame(data_perkotaan)
df_perdesaan = pd.DataFrame(data_perdesaan)

print("DataFrame Perkotaan:")
print(df_perkotaan)

print("\nDataFrame Perdesaan:")
print(df_perdesaan)
# Out:
# DataFrame Perkotaan:
#   Rumah Tangga  Perkotaan
# 0            A        110
# 1            B        102
# 2            C         98
# 3            D        107
# 4            E        120
# 5            F        125
# 6            G        115
# 7            H         95
# 8            I        122
# 9            J        112
#
# DataFrame Perdesaan:
#   Rumah Tangga  Perdesaan
# 0            P         54
# 1            Q         45
# 2            R         60
# 3            S         55
# 4            T         75
# 5            U         72
# 6            V         62
# 7            W         65
# 8            X         85
# 9            Y         35

# %%
sns.barplot(x='Rumah Tangga', y='Perkotaan', data=df_perkotaan)
plt.title('Data Perkotaan')

# %%
# Combine the data into a single DataFrame for plotting
combined_data = pd.concat([
    df_perkotaan.rename(columns={'Perkotaan': 'Value'}).assign(Category='Perkotaan'),
    df_perdesaan.rename(columns={'Perdesaan': 'Value'}).assign(Category='Perdesaan')
])

# Create a bar plot
sns.barplot(x='Rumah Tangga', y='Value', hue='Category', data=combined_data)
plt.title('Perbandingan Konsumsi Perkotaan and Perdesaan')
plt.ylabel('Konsumsi')
plt.xlabel('Rumah Tangga')
plt.legend(title='Konsumsi')
plt.show()

# %%
# ukuran pemusatan
rand_mean = np.mean(df_perkotaan['Perkotaan'])
rand_median = np.median(df_perkotaan['Perkotaan'])
rand_mode = statistics.mode(df_perkotaan['Perkotaan'])
q1 = stats.scoreatpercentile(df_perkotaan['Perkotaan'], 25)
q2 = stats.scoreatpercentile(df_perkotaan['Perkotaan'], 50)
q3 = stats.scoreatpercentile(df_perkotaan['Perkotaan'], 75)

# ukuran pesebaran
range = max(df_perkotaan['Perkotaan']) - min(df_perkotaan['Perkotaan'])
varians = np.var(df_perkotaan['Perkotaan'], ddof=1)
std_dev = np.std(df_perkotaan['Perkotaan'], ddof=1)
koefisien_varians = (std_dev / rand_mean) * 100

# %%
print("berikut ukuran pemusatan dari data perkotaan")
print(f'mean = {rand_mean}')
print(f'median = {rand_median}')
print(f'modus = {rand_mode}')
print(f'quartile 1 = {q1}')
print(f'quartile 2 = {q2}')
print(f'quartile 3 = {q3}')

print("berikut ukuran pemusatan dari data")
print(f'range = {range}')
print(f'varians = {varians}')
print(f'standar deviasi = {std_dev}')
print(f'koefisien varians = {koefisien_varians:.2f}%')
# Out:
# berikut ukuran pemusatan dari data perkotaan
# mean = 110.6
# median = 111.0
# modus = 110
# quartile 1 = 103.25
# quartile 2 = 111.0
# quartile 3 = 118.75
# berikut ukuran pemusatan dari data
# range = 30
# varians = 104.04444444444444
# standar deviasi = 10.200217862597075
# koefisien varians = 9.22%

# %%
# ukuran pemusatan
rand_meand = np.mean(df_perdesaan['Perdesaan'])
rand_mediand = np.median(df_perdesaan['Perdesaan'])
rand_moded = statistics.mode(df_perdesaan['Perdesaan'])
q1d = stats.scoreatpercentile(df_perdesaan['Perdesaan'], 25)
q2d = stats.scoreatpercentile(df_perdesaan['Perdesaan'], 50)
q3d = stats.scoreatpercentile(df_perdesaan['Perdesaan'], 75)

# ukuran pesebaran
ranged = max(df_perdesaan['Perdesaan']) - min(df_perdesaan['Perdesaan'])
variansd = np.var(df_perdesaan['Perdesaan'], ddof=1)
std_devd = np.std(df_perdesaan['Perdesaan'], ddof=1)
koefisien_variansd = (std_devd / rand_meand) * 100

# %%
print("berikut ukuran pemusatan dari data perdesaan")
print(f'mean = {rand_meand}')
print(f'median = {rand_mediand}')
print(f'modus = {rand_moded}')
print(f'quartile 1 = {q1d}')
print(f'quartile 2 = {q2d}')
print(f'quartile 3 = {q3d}')

print("berikut ukuran pemusatan dari data")
print(f'range = {ranged}')
print(f'varians = {variansd}')
print(f'standar deviasi = {std_devd}')
print(f'koefisien varians = {koefisien_variansd:.2f}%')
# Out:
# berikut ukuran pemusatan dari data perdesaan
# mean = 60.8
# median = 61.0
# modus = 54
# quartile 1 = 54.25
# quartile 2 = 61.0
# quartile 3 = 70.25
# berikut ukuran pemusatan dari data
# range = 50
# varians = 214.17777777777778
# standar deviasi = 14.634813896246778
# koefisien varians = 24.07%

# %%
# Create a dictionary to store the results
results = {
    'Metric': ['Mean', 'Median', 'Mode', 'Q1', 'Q2', 'Q3', 'Range', 'Variance', 'Std Dev', 'Coeff of Variation'],
    'Perkotaan': [rand_mean, rand_median, rand_mode, q1, q2, q3, range, varians, std_dev, koefisien_varians],
    'Perdesaan': [rand_meand, rand_mediand, rand_moded, q1d, q2d, q3d, ranged, variansd, std_devd, koefisien_variansd]
}

# Create a DataFrame
df_results = pd.DataFrame(results)

# Display the DataFrame
df_results
# Out:
#                Metric   Perkotaan   Perdesaan
# 0                Mean  110.600000   60.800000
# 1              Median  111.000000   61.000000
# 2                Mode  110.000000   54.000000
# 3                  Q1  103.250000   54.250000
# 4                  Q2  111.000000   61.000000
# 5                  Q3  118.750000   70.250000
# 6               Range   30.000000   50.000000
# 7            Variance  104.044444  214.177778
# 8             Std Dev   10.200218   14.634814
# 9  Coeff of Variation    9.222620   24.070418

# %%
# Convert the results dictionary to a DataFrame for easier plotting
df_results_melted = df_results.melt(id_vars='Metric', var_name='Category', value_name='Value')

# Create a bar plot to compare the metrics
plt.figure(figsize=(12, 6))
sns.barplot(x='Metric', y='Value', hue='Category', data=df_results_melted)
plt.title('Comparison of Metrics Between Perkotaan and Perdesaan')
plt.ylabel('Value')
plt.xlabel('Metric')
plt.xticks(rotation=45)
plt.legend(title='Category')
plt.tight_layout()
plt.show()

# %%
df_results_melted
# Out:
#                 Metric   Category       Value
# 0                 Mean  Perkotaan  110.600000
# 1               Median  Perkotaan  111.000000
# 2                 Mode  Perkotaan  110.000000
# 3                   Q1  Perkotaan  103.250000
# 4                   Q2  Perkotaan  111.000000
# 5                   Q3  Perkotaan  118.750000
# 6                Range  Perkotaan   30.000000
# 7             Variance  Perkotaan  104.044444
# 8              Std Dev  Perkotaan   10.200218
# 9   Coeff of Variation  Perkotaan    9.222620
# 10                Mean  Perdesaan   60.800000
# 11              Median  Perdesaan   61.000000
# 12                Mode  Perdesaan   54.000000
# 13                  Q1  Perdesaan   54.250000
# 14                  Q2  Perdesaan   61.000000
# 15                  Q3  Perdesaan   70.250000
# 16               Range  Perdesaan   50.000000
# 17            Variance  Perdesaan  214.177778
# 18             Std Dev  Perdesaan   14.634814
# ...

# %%
sns.kdeplot(df_perkotaan['Perkotaan'], color='red', linewidth=2)
plt.axvline(x=rand_mean, color='red', linestyle='--', label='mean', linewidth=2)
plt.axvline(x=rand_median, color='blue', linestyle='dashdot', label='median', linewidth=2)
plt.axvline(x=rand_mode, color='green', linestyle='dashdot', label='mode', linewidth=2)
plt.axvline(x=q1, color='black', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q2, color='yellow', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q3, color='orange', linestyle='dashdot', label='q3', linewidth=2)
plt.legend()
plt.show()

# %%
sns.histplot(df_perkotaan, kde=True)
plt.axvline(x=rand_mean, color='red', linestyle='--', label='mean', linewidth=2)
plt.axvline(x=rand_median, color='blue', linestyle='dashdot', label='median', linewidth=2)
plt.axvline(x=rand_mode, color='green', linestyle='dashdot', label='mode', linewidth=2)
plt.axvline(x=q1, color='black', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q2, color='yellow', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q3, color='orange', linestyle='dashdot', label='q3', linewidth=2)
plt.legend()
plt.show()

# %%
sns.histplot(df_perkotaan['Perkotaan'], kde=True, color='blue', label='Perkotaan')
plt.axvline(x=rand_mean, color='red', linestyle='--', label='mean', linewidth=2)
plt.axvline(x=rand_median, color='blue', linestyle='dashdot', label='median', linewidth=2)
plt.axvline(x=rand_mode, color='green', linestyle='dashdot', label='mode', linewidth=2)
plt.axvline(x=q1, color='black', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q2, color='yellow', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q3, color='orange', linestyle='dashdot', label='q3', linewidth=2)

sns.histplot(df_perdesaan['Perdesaan'], kde=True, color='red', label='Perdesaan')
plt.axvline(x=rand_meand, color='red', linestyle='--', label='mean', linewidth=2)
plt.axvline(x=rand_mediand, color='blue', linestyle='dashdot', label='median', linewidth=2)
plt.axvline(x=rand_moded, color='green', linestyle='dashdot', label='mode', linewidth=2)
plt.axvline(x=q1d, color='black', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q2d, color='yellow', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q3d, color='orange', linestyle='dashdot', label='q3', linewidth=2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 8))  # Increase the canvas size
sns.histplot(df_perkotaan['Perkotaan'], kde=True, color='blue', label='Perkotaan')
plt.axvline(x=rand_mean, color='red', linestyle='--', label='mean', linewidth=2)
plt.axvline(x=rand_median, color='blue', linestyle='dashdot', label='median', linewidth=2)
plt.axvline(x=rand_mode, color='green', linestyle='dashdot', label='mode', linewidth=2)
plt.axvline(x=q1, color='black', linestyle='dashdot', label='q1', linewidth=2)
plt.axvline(x=q2, color='yellow', linestyle='dashdot', label='q2', linewidth=2)
plt.axvline(x=q3, color='orange', linestyle='dashdot', label='q3', linewidth=2)

sns.histplot(df_perdesaan['Perdesaan'], kde=True, color='red', label='Perdesaan')
plt.axvline(x=rand_meand, color='red', linestyle='--', label='mean (Perdesaan)', linewidth=2)
plt.axvline(x=rand_mediand, color='blue', linestyle='dashdot', label='median (Perdesaan)', linewidth=2)
plt.axvline(x=rand_moded, color='green', linestyle='dashdot', label='mode (Perdesaan)', linewidth=2)
plt.axvline(x=q1d, color='black', linestyle='dashdot', label='q1 (Perdesaan)', linewidth=2)
plt.axvline(x=q2d, color='yellow', linestyle='dashdot', label='q2 (Perdesaan)', linewidth=2)
plt.axvline(x=q3d, color='orange', linestyle='dashdot', label='q3 (Perdesaan)', linewidth=2)

plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1))  # Adjust legend position
plt.tight_layout()  # Optimize layout
plt.xlabel('Konsumsi')
plt.ylabel('Frekuensi')
plt.title('Histogram Perkotaan and Perdesaan dengan KDE')
plt.show()
